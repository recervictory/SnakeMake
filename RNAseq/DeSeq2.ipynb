# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import dash_bio as dashbio

# %%
df = pd.read_csv('results/results_airway.tsv',index_col=0, sep='\t')
df.head()
# Out:
#                     baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003   709.698552       -0.383074  0.100462 -3.813133  0.000137
# ENSG00000000419   521.040353        0.205022  0.111299  1.842083  0.065463
# ENSG00000000457   237.510888        0.036148  0.140619  0.257065  0.797129
# ENSG00000000460    58.018762       -0.091646  0.278242 -0.329375  0.741872
# ENSG00000000971  5825.513700        0.424604  0.089439  4.747404  0.000002
#
#                      padj    symbol   entrez          ENSEMBL
# ENSG00000000003  0.001106    TSPAN6   7105.0  ENSG00000000003
# ENSG00000000419  0.186488      DPM1   8813.0  ENSG00000000419
# ENSG00000000457  0.905422     SCYL3  57147.0  ENSG00000000457
# ENSG00000000460  0.877333  C1orf112  55732.0  ENSG00000000460
# ENSG00000000971  0.000025       CFH   3075.0  ENSG00000000971

# %%
df['negative_padj'] = np.log10(df['padj']) * (-1)
df.head()
# Out:
#                     baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003   709.698552       -0.383074  0.100462 -3.813133  0.000137
# ENSG00000000419   521.040353        0.205022  0.111299  1.842083  0.065463
# ENSG00000000457   237.510888        0.036148  0.140619  0.257065  0.797129
# ENSG00000000460    58.018762       -0.091646  0.278242 -0.329375  0.741872
# ENSG00000000971  5825.513700        0.424604  0.089439  4.747404  0.000002
#
#                      padj    symbol   entrez          ENSEMBL  negative_padj
# ENSG00000000003  0.001106    TSPAN6   7105.0  ENSG00000000003       2.956396
# ENSG00000000419  0.186488      DPM1   8813.0  ENSG00000000419       0.729350
# ENSG00000000457  0.905422     SCYL3  57147.0  ENSG00000000457       0.043149
# ENSG00000000460  0.877333  C1orf112  55732.0  ENSG00000000460       0.056836
# ENSG00000000971  0.000025       CFH   3075.0  ENSG00000000971       4.600889

# %%
import plotly.express as px

fig = px.scatter(df, x='log2FoldChange', y='negative_padj', color='negative_padj',hover_name='symbol')
fig.show()

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
from statsmodels.stats import multitest

# Load the data
data = pd.read_csv('results/results_airway.tsv', sep='\t')

# Filter the data
filterThreshold = 10
use = data['baseMean'] > filterThreshold

# Get the p-values
pvalues = data['pvalue']

# Perform multiple testing correction
_, pvalues_corrected, _, _ = multitest.multipletests(pvalues, alpha=0.001, method='fdr_bh')

# Create the histogram trace for non-significant p-values
hist1 = go.Histogram(
    x=pvalues[~use],
    name='do not pass',
    xbins=dict(
        start=0,
        end=1,
        size=0.02
    ),
    
)

# Create the histogram trace for significant p-values
hist2 = go.Histogram(
    x=pvalues[use],
    name='pass',
    xbins=dict(
        start=0,
        end=1,
        size=0.02
    ),
    
)

# Combine the traces into a data list
data = [hist1, hist2]

# Define the layout
layout = go.Layout(
    title='Histogram of p-values',
    xaxis=dict(
        title='p-value',
        range=[0, 1]
    ),
    yaxis=dict(
        title='frequency'
    ),
    bargap=0.1,
    bargroupgap=0.1
)

# Create the figure
fig = go.Figure(data=data, layout=layout)

# Show the figure
fig.show()

# %%
import plotly.express as px

def ma_plot(df, base_mean_col, log2FoldChange_col, pvalue_col):
    # create a new column with modified p-values
    df[base_mean_col] = np.log10(df[base_mean_col])
    
    # create a new column to indicate color based on significance and direction of change
    df['color'] = np.where((df[pvalue_col] < 0.05) & (df[log2FoldChange_col] > 0), 'Up Regulated',
                           np.where((df[pvalue_col] < 0.05) & (df[log2FoldChange_col] < 0), 'Down Regulated',
                                    np.where(df[pvalue_col] >= 0.05, 'Non Significant', '')))
    
    # create a Plotly scatter plot
    fig = px.scatter(df, x=base_mean_col, y=log2FoldChange_col, color='color', color_discrete_map= {
        'Upregulated' : 'red', 'Downregulated': 'blue', 'Non Significant' : '#fff'
    })
    
    # set x and y axis labels
    fig.update_xaxes(title_text='Base Mean')
    fig.update_yaxes(title_text='Log2 Fold Change')
    
    # set title
    up_count = len(df[(df[pvalue_col] < 0.05) & (df[log2FoldChange_col] > 0)])
    down_count = len(df[(df[pvalue_col] < 0.05) & (df[log2FoldChange_col] < 0)])
    non_sig_count = len(df[df[pvalue_col] >= 0.05])
    fig.update_layout(title=f'MA Plot of Differential Gene Expression ({up_count} up, {down_count} down, {non_sig_count} non-significant)')
    
    return fig

# %%
fig = ma_plot(df, 'baseMean', 'log2FoldChange', 'pvalue')
fig.show()

# %%
with open("graph.txt", "r") as f:
    dot_graph = f.read()

# %%
# !pip install  graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      -------------------------------------- 47.0/47.0 kB 584.1 kB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1

# %%
dot_graph
# Out:
# 'digraph snakemake_dag {\n\tgraph [bb="0,0,562.7,329",\n\t\tbgcolor=white,\n\t\tmargin=0\n\t];\n\tnode [fontname=sans,\n\t\tfontsize=10,\n\t\tlabel="\\N",\n\t\tpenwidth=2,\n\t\tshape=box,\n\t\tstyle=rounded\n\t];\n\tedge [color=grey,\n\t\tpenwidth=2\n\t];\n\t0\t[color="0.42 0.6 0.85",\n\t\theight=0.5,\n\t\tlabel=all,\n\t\tpos="287.51,18",\n\t\tstyle="rounded,dashed",\n\t\twidth=0.75];\n\t1\t[color="0.50 0.6 0.85",\n\t\theight=0.5,\n\t\tlabel=starMapping,\n\t\tpos="240.51,90",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.0694];\n\t1 -> 0\t[pos="e,276.03,36.104 252.13,71.697 257.65,63.474 264.36,53.483 270.44,44.421"];\n\t2\t[color="0.17 0.6 0.85",\n\t\theight=0.5,\n\t\tlabel=starIndexing,\n\t\tpos="504.51,162",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.0694];\n\t2 -> 1\t[pos="e,279.15,105.17 465.88,146.83 462.73,145.83 459.58,144.87 456.51,144 386.05,124.06 363.8,128.38 289.04,107.93"];\n\t13\t[color="0.50 0.6 0.85",\n\t\theight=0.5,\n\t\tlabel=starMapping,\n\t\tpos="335.51,90",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.0694];\n\t2 -> 13\t[pos="e,374.1,106.98 465.74,144.94 441.27,134.8 409.47,121.63 383.42,110.84"];\n\t3\t[color="0.08 0.6 0.85",\n\t\theight=0.5,\n\t\tlabel=cutAdapt,\n\t\tpos="176.51,234",\n\t\tstyle="rounded,dashed",\n\t\twidth=0.83333];\n\t3 -> 1\t[pos="e,201.89,94.12 146.51,228.96 88.087,219.88 -31.818,194.58 8.513,144 30.974,115.83 130.51,101.44 191.68,95.135"];\n\t8\t[color="0.25 0.6 0.85",\n\t\theight=0.5,\n\t\tlabel="trimmed_fastqc\\nread: R1",\n\t\tpos="176.51,162",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.3056];\n\t3 -> 8\t[pos="e,176.51,180.1 176.51,215.7 176.51,207.98 176.51,198.71 176.51,190.11"];\n\t9\t[color="0.25 0.6 0.85",\n\t\theight=0.5,\n\t\tlabel="trimmed_fastqc\\nread: R2",\n\t\tpos="64.513,162",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.3056];\n\t3 -> 9\t[pos="e,92.017,180.19 149.11,215.88 134.61,206.81 116.6,195.55 100.93,185.76"];\n\t4\t[color="0.00 0.6 0.85",\n\t\theight=0.56944,\n\t\tlabel="fastQC\\nread: R1\\nsample: control",\n\t\tpos="284.51,308.5",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.2778];\n\t4 -> 3\t[pos="e,202.09,252.17 255.29,287.88 241.53,278.64 225.02,267.57 210.69,257.94"];\n\t11\t[color="0.08 0.6 0.85",\n\t\theight=0.5,\n\t\tlabel=cutAdapt,\n\t\tpos="288.51,234",\n\t\tstyle="rounded,dashed",\n\t\twidth=0.83333];\n\t4 -> 11\t[pos="e,287.56,252.32 285.61,287.69 286.04,279.91 286.54,270.84 287,262.45"];\n\t5\t[color="0.00 0.6 0.85",\n\t\theight=0.56944,\n\t\tlabel="fastQC\\nread: R2\\nsample: control",\n\t\tpos="394.51,308.5",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.2778];\n\t5 -> 3\t[pos="e,206.63,244.53 348.33,291.03 345.35,289.99 342.39,288.98 339.51,288 297.64,273.77 249.45,258.2 216.38,247.64"];\n\t5 -> 11\t[pos="e,313.61,252.17 365.83,287.88 352.32,278.64 336.13,267.57 322.06,257.94"];\n\t6\t[color="0.00 0.6 0.85",\n\t\theight=0.56944,\n\t\tlabel="fastQC\\nread: R1\\nsample: drug",\n\t\tpos="82.513,308.5",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.1111];\n\t6 -> 3\t[pos="e,154.37,252.08 108.2,287.69 119.95,278.63 133.95,267.83 146.21,258.37"];\n\t6 -> 11\t[pos="e,258.25,244.69 122.56,291.36 125.58,290.21 128.59,289.07 131.51,288 170.99,273.49 216.57,258.27 248.42,247.88"];\n\t7\t[color="0.00 0.6 0.85",\n\t\theight=0.56944,\n\t\tlabel="fastQC\\nread: R2\\nsample: drug",\n\t\tpos="180.51,308.5",\n\t\tstyle="rounded,dashed",\n\t\twidth=1.1111];\n\t7 -> 3\t[pos="e,177.47,252.32 179.42,287.69 178.99,279.91 178.49,270.84 178.03,262.45"];\n\t7 -> 11\t[pos="e,262.94,252.17 209.74,287.88 223.5,278.64 240,267.57 254.34,257.94"];\n\t8 -> 1\t[pos="e,224.87,108.1 192.33,143.7 200.08,135.22 209.55,124.86 218.04,115.58"];\n\t8 -> 13\t[pos="e,296.74,108.07 215.41,143.88 237.15,134.31 264.42,122.3 287.48,112.15"];\n\t9 -> 1\t[pos="e,201.8,106.4 107.57,143.88 133.22,133.67 165.83,120.7 192.34,110.16"];\n\t9 -> 13\t[pos="e,296.92,105.43 111.79,146.34 114.74,145.53 117.66,144.74 120.51,144 191.41,125.68 213.32,128.73 287.15,108.2"];\n\t10\t[color="0.25 0.6 0.85",\n\t\theight=0.5,\n\t\t ...

# %%
import sys
import os
from graphviz import render, Source

if len(sys.argv) < 2:
    print("Please provide the path of the DOT file as an argument")
    sys.exit()

input_path = sys.argv[1]

if not os.path.exists(input_path):
    print("The file path provided does not exist")
    sys.exit()

# Read the DOT graph from the input file
with open(input_path, "r") as f:
    dot_graph = f.read()

# Render the graph using Graphviz
graph = Source(dot_graph)
graph.format = "png"

# Save the output file with the same name as the input file
output_path = os.path.splitext(input_path)[0] + ".png"
graph.render(output_path, view=True)

graph = graphviz.Source(dot_graph)

# Render the graph to a PNG image file
graph.format = 'png'
graph.render('example_graph', view=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80         else:
# ---> 81             proc = subprocess.run(cmd, **kwargs)
#      82     except OSError as e:
#
# c:\Users\acer\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# c:\Users\acer\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# c:\Users\acer\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20184\999029269.py in <module>
#       5 # Render the graph to a PNG image file
#       6 graph.format = 'png'
# ----> 7 graph.render('example_graph', view=True)
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\rendering.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     120         args.append(filepath)
#     121
# --> 122         rendered = self._render(*args, **kwargs)
#     123
#     124         if cleanup:
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\backend\rendering.py in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     322     cmd += args
#     323
# --> 324     execute.run_check(cmd,
#     325                       cwd=filepath.parent if filepath.parent.parts else None,
#     326                       quiet=quiet,
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82     except OSError as e:
#      83         if e.errno == errno.ENOENT:
# ---> 84             raise ExecutableNotFound(cmd) from e
#      85         raise
#      86
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %%
from graphviz import render, Source

# %%
graph = Source(dot_graph)
graph.format = "png"

# %%
graph.render('example_graph', view=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80         else:
# ---> 81             proc = subprocess.run(cmd, **kwargs)
#      82     except OSError as e:
#
# c:\Users\acer\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# c:\Users\acer\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# c:\Users\acer\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20184\3571006758.py in <module>
# ----> 1 graph.render('example_graph', view=True)
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\rendering.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     120         args.append(filepath)
#     121
# --> 122         rendered = self._render(*args, **kwargs)
#     123
#     124         if cleanup:
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\backend\rendering.py in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     322     cmd += args
#     323
# --> 324     execute.run_check(cmd,
#     325                       cwd=filepath.parent if filepath.parent.parts else None,
#     326                       quiet=quiet,
#
# c:\Users\acer\anaconda3\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82     except OSError as e:
#      83         if e.errno == errno.ENOENT:
# ---> 84             raise ExecutableNotFound(cmd) from e
#      85         raise
#      86
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH
